# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key="AIzaSyBEXyEF7zF7FbHVLbYML_Pw-avEftGaVjw")

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID              City Country  Max Temp      Current Description  \
# 0         2             Kapaa      US     82.40                clear sky
# 1         4            Faanui      PF     80.29               light rain
# 2         5          Victoria      HK     75.00          overcast clouds
# 3         9  Puerto Escondido      MX     78.80            moderate rain
# 4        12              Sibu      MY     78.80         scattered clouds
# 5        13        Butaritari      KI     82.04            broken clouds
# 6        14            Laguna      US     77.00                clear sky
# 7        21      Luis Correia      BR     80.33         scattered clouds
# 8        25           Samarai      PG     81.72               light rain
# 9        26           Rikitea      PF     75.45          overcast clouds
# 10       27      Umm Kaddadah      SD     81.55                clear sky
# 11       29      Port Moresby      PG     86.00                     haze
# 12       35              Hilo      US     80.60            moderate rain
# 13       41             Conde      BR     77.00         scattered clouds
# 14       45          Semporna      MY     80.60               few clouds
# 15       52            Ixtapa      MX     84.20                clear sky
# 16       57     Makakilo City      US     84.20          overcast clouds
# 17       60          Meulaboh      ID     77.90          overcast clouds
# 18       62        The Valley      AI     84.20         scattered clouds
# 19       67   Arraial Do Cabo      BR     75.11               light rain
# 20       73         Busselton      AU     78.01                clear sky
# 21       74           Veraval      IN     77.22                clear sky
# 22       78         Hithadhoo      MV     82.98            broken clouds
# 23       84             Dakar      SN     82.40                clear sky
# 24       94            Avarua      CK     77.00          overcast clouds
# 25      100              Poum      NC     77.54          overcast clouds
# 26      101             Alofi      NU     77.00  light intensity drizzle
# 27      113            Sorong      ID     83.34            broken clouds
# 28      116            Atuona      PF     78.12          overcast clouds
# 29      126         Bathsheba      BB     77.00              shower rain
# 30      134          Lorengau      PG     84.49            moderate rain
# 31      136           Kavieng      PG     80.85            moderate rain
# 32      144          Pedregal      PA     80.01               light rain
# 33      156        Manzanillo      CU     77.70     heavy intensity rain
# 34      157     Cockburn Town      TC     82.49               few clouds
# 35      158        Georgetown      MY     80.60               few clouds
# 36      159            Sabang      ID     82.31            broken clouds
# 37      160             Vaini      TO     77.00               few clouds
# 38      161         Thinadhoo      MV     82.83               few clouds
# 39      164      Areia Branca      BR     77.61                clear sky
# 40      171          Celestun      MX     79.63               light rain
# 41      172             Chauk      MM     78.37               light rain
# 42      178           Kahului      US     86.00         scattered clouds
# 43      183         Tecoanapa      MX     80.55               light rain
# 44      185            Vanimo      PG     77.02               light rain
# 45      190             Wagar      SD     75.97                clear sky
# 46      195           Miramar      US     82.40                clear sky
# 47      199        Vila Velha      BR     80.60            moderate rain
# 48      202            Palmas      BR     82.40               light rain
# 49      203            Dingle      PH     82.11          very heavy rain
#
#       Lat     Lng                                         Hotel Name
# 0   22.08 -159.32             Sheraton Kauai Resort at Coconut Beach
# 1  -16.48 -151.75                 Bora-Bora Pearl Beach Resort & Spa
# 2   22.29  114.16                                 Mini Hotel Central
# 3   15.85  -97.07                      Aldea del Bazar Hotel and Spa
# 4    2.30  111.82                                  RH HOTEL (4 Star)
# 5    3.07  172.79                                 Isles Sunset Lodge
# 6   38.42 -121.42  Holiday Inn Express & Suites Elk Grove Central...
# 7   -2.88  -41.67                                    Hotel Amarração
# 8  -10.62  150.67                                          Nuli Sapi
# 9  -23.12 -134.97                                     Pension Maro'i
# 10  13.60   26.69                                                NaN
# 11  -9.44  147.18                                       Lamana Hotel
# 12  19.73 -155.09                                Hilo Hawaiian Hotel
# 13  -7.26  -34.91                                 Pousada Beija Flor
# 14   4.48  118.61                 Han Palace Hotel, Semporna, Sabah.
# 15  20.70 -105.20                      Container Inn Puerto Vallarta
# 16  21.35 -158.09                     Marriott's Ko Olina Beach Club
# 17   4.14   96.13                                          Kost Pria
# 18  18.22  -63.06                       CeBlue Villas & Beach Resort
# 19 -22.97  -42.03                                Pousada Porto Praia
# 20 -33.65  115.33                            Observatory Guest House
# 21  20.90   70.37                                  Lords Inn Somnath
# 22  -0.60   73.08                                  Scoop Guest House
# 23  14.69  -17.44                                      Novotel Dakar
# 24 -21.21 -159.78                                       Paradise Inn
# 25 -20.23  164.02                                        Gîte kajeon
# 26 -19.06 -169.92                                      Taloa Heights
# 27  -0.88  131.25                                    The Waigo Hotel
# 28  -9.80 -139.03                                        Villa Enata
# 29  13.22  -59.52                                     Atlantis Hotel
# 30  -2.02  147.27                         Lorengau Harbourside Hotel
# 31  -2.57  150.80                                Nusa Island Retreat
# 32   8.37  -82.43                                     Kibutz de Rita
# 33  20.34  -77.12                                     Adrian & Tonia
# 34  21.46  -71.14                                 Osprey Beach Hotel
# 35   5.41  100.34                                     Cititel Penang
# 36   5.89   95.32                                        Hotel Citra
# 37 -21.20 -175.20                                Keleti Beach Resort
# 38   0.53   72.93                                                NaN
# 39  -4.96  -37.14                           Areia Branca Apart Hotel
# 40  20.87  -90.40                                       Posada Lilia
# 41  20.88   94.82                                Bo Khin Guest House
# 42  20.89 -156.47                                 Maui Seaside Hotel
# 43  16.52  -98.75                                    Hotel Manglares
# 44  -2.67  141.30                              Vahmoneh Lodge Vanimo
# 45  16.15   36.20                                                NaN
# 46  25.99  -80.23                                      Stadium Hotel
# 47 -20.33  -40.29                               Hotel Vitória Palace
# 48 -10.21  -48.36                                Hotel Lago da Palma
# 49  11.00  122.67                                        Camp Pasica

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current description</dt><dd>{Current Description}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Miramar']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Miramar']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Laguna']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Tecoanapa'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Ixtapa'] 
vacation_stop3
# Out:
#     City_ID    City Country  Max Temp Current Description   Lat    Lng  \
# 15       52  Ixtapa      MX      84.2           clear sky  20.7 -105.2
#
#                        Hotel Name
# 15  Container Inn Puerto Vallarta

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.iloc[0,5:7].to_numpy()
end = vacation_end.iloc[0,5:7].to_numpy()
stop1 = vacation_stop1.iloc[0,5:7].to_numpy()
stop2 = vacation_stop2.iloc[0,5:7].to_numpy()
stop3 = vacation_stop3.iloc[0,5:7].to_numpy()

start
# Out:
# array([25.99, -80.23], dtype=object)

# %%
end
# Out:
# array([25.99, -80.23], dtype=object)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure(center=(22, -159), zoom_level = 7)
# Kapaa = start
Laguna = stop1
Tecoanapa = stop2
Ixtapa = stop3 
roadtrip = gmaps.directions_layer(start, end, 
                                  waypoints=[Laguna, Tecoanapa, Ixtapa],
                                  travel_mode="DRIVING")

fig.add_layer(roadtrip)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID       City Country  Max Temp Current Description    Lat     Lng  \
# 0      195    Miramar      US     82.40           clear sky  25.99  -80.23
# 1       14     Laguna      US     77.00           clear sky  38.42 -121.42
# 2      183  Tecoanapa      MX     80.55          light rain  16.52  -98.75
# 3       52     Ixtapa      MX     84.20           clear sky  20.70 -105.20
#
#                                           Hotel Name
# 0                                      Stadium Hotel
# 1  Holiday Inn Express & Suites Elk Grove Central...
# 2                                    Hotel Manglares
# 3                      Container Inn Puerto Vallarta

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

locations = itinerary_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
